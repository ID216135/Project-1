# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import hvplot.pandas
import requests

# %%
# Importing Medicare data
medicare_data_df = pd.read_csv("Data\Medicare_Telehealth_Trends_Q1_2023.csv")
medicare_data_df.head()
# Out:
#    Year quarter Bene_Geo_Desc Bene_Mdcd_Mdcr_Enrl_Stus      Bene_Race_Desc  \
# 0  2023       1       Wyoming            Medicare Only                 All
# 1  2023       1       Wyoming      Medicare & Medicaid                 All
# 2  2023       1       Wyoming                      All       Other/Unknown
# 3  2023       1       Wyoming                      All  Non-Hispanic White
# 4  2023       1       Wyoming                      All            Hispanic
#
#   Bene_Sex_Desc Bene_Mdcr_Entlmt_Stus Bene_Age_Desc Bene_RUCA_Desc  \
# 0           All                   All           All            All
# 1           All                   All           All            All
# 2           All                   All           All            All
# 3           All                   All           All            All
# 4           All                   All           All            All
#
#    Total_Bene_TH_Elig  Total_PartB_Enrl  Total_Bene_Telehealth  Pct_Telehealth
# 0             57582.0           87532.0                 3976.0          0.0690
# 1              7781.0           10302.0                 1373.0          0.1765
# 2                 NaN               NaN                    NaN             NaN
# 3             59795.0           89194.0                 4813.0          0.0805
# 4              2476.0            3786.0                  213.0          0.0860

# %%
#Checking where NaN values come from
medicare_data_df.loc[medicare_data_df["Total_Bene_TH_Elig"].isna()].groupby(["Bene_Race_Desc","Bene_RUCA_Desc"]).count()
# Out:
#                                               Year  quarter  Bene_Geo_Desc  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All               16       16             16
#                               Rural             16       16             16
#                               Unknown          864      864            864
# American Indian/Alaska Native All                8        8              8
#                               Unknown           16       16             16
# Asian/Pacific Islander        Unknown           16       16             16
# Black/African American        Unknown           16       16             16
# Hispanic                      Unknown           16       16             16
# Non-Hispanic White            Unknown           16       16             16
# Other/Unknown                 All             1008     1008           1008
#                               Rural             16       16             16
#                               Unknown           16       16             16
#                               Urban             16       16             16
#
#                                               Bene_Mdcd_Mdcr_Enrl_Stus  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                                   16
#                               Rural                                 16
#                               Unknown                              864
# American Indian/Alaska Native All                                    8
#                               Unknown                               16
# Asian/Pacific Islander        Unknown                               16
# Black/African American        Unknown                               16
# Hispanic                      Unknown                               16
# Non-Hispanic White            Unknown                               16
# Other/Unknown                 All                                 1008
#                               Rural                                 16
#                               Unknown                               16
#                               Urban                                 16
#
#                                               Bene_Sex_Desc  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                        16
#                               Rural                      16
#                               Unknown                   864
# American Indian/Alaska Native All                         8
#                               Unknown                    16
# Asian/Pacific Islander        Unknown                    16
# Black/African American        Unknown                    16
# Hispanic                      Unknown                    16
# Non-Hispanic White            Unknown                    16
# Other/Unknown                 All                      1008
#                               Rural                      16
#                               Unknown                    16
#                               Urban                      16
#
#                                               Bene_Mdcr_Entlmt_Stus  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                                16
#                               Rural                              16
#                               Unknown                           864
# American Indian/Alaska Native All                                 8
#                               Unknown                            16
# Asian/Pacific Islander        Unknown                            16
# Black/African American        Unknown                            16
# Hispanic                      Unknown                            16
# Non-Hispanic White            Unknown                            16
# Other/Unknown                 All                              1008
#                               Rural                              16
#                               Unknown                            16
#                               Urban                              16
#
#                                               Bene_Age_Desc  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                        16
#                               Rural                      16
#                               Unknown                   864
# American Indian/Alaska Native All                         8
#                               Unknown                    16
# Asian/Pacific Islander        Unknown                    16
# Black/African American        Unknown                    16
# Hispanic                      Unknown                    16
# Non-Hispanic White            Unknown                    16
# Other/Unknown                 All                      1008
#                               Rural                      16
#                               Unknown                    16
#                               Urban                      16
#
#                                               Total_Bene_TH_Elig  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                              0
#                               Rural                            0
#                               Unknown                          0
# American Indian/Alaska Native All                              0
#                               Unknown                          0
# Asian/Pacific Islander        Unknown                          0
# Black/African American        Unknown                          0
# Hispanic                      Unknown                          0
# Non-Hispanic White            Unknown                          0
# Other/Unknown                 All                              0
#                               Rural                            0
#                               Unknown                          0
#                               Urban                            0
#
#                                               Total_PartB_Enrl  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                            0
#                               Rural                          0
#                               Unknown                        0
# American Indian/Alaska Native All                            0
#                               Unknown                        0
# Asian/Pacific Islander        Unknown                        0
# Black/African American        Unknown                        0
# Hispanic                      Unknown                        0
# Non-Hispanic White            Unknown                        0
# Other/Unknown                 All                            0
#                               Rural                          0
#                               Unknown                        0
#                               Urban                          0
#
#                                               Total_Bene_Telehealth  \
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                                 0
#                               Rural                               2
#                               Unknown                             0
# American Indian/Alaska Native All                                 1
#                               Unknown                             0
# Asian/Pacific Islander        Unknown                             0
# Black/African American        Unknown                             0
# Hispanic                      Unknown                             0
# Non-Hispanic White            Unknown                             0
# Other/Unknown                 All                                 0
#                               Rural                               0
#                               Unknown                             0
#                               Urban                               0
#
#                                               Pct_Telehealth
# Bene_Race_Desc                Bene_RUCA_Desc
# All                           All                          0
#                               Rural                        0
#                               Unknown                      0
# American Indian/Alaska Native All                          0
#                               Unknown                      0
# Asian/Pacific Islander        Unknown                      0
# Black/African American        Unknown                      0
# Hispanic                      Unknown                      0
# Non-Hispanic White            Unknown                      0
# Other/Unknown                 All                          0
#                               Rural                        0
#                               Unknown                      0
#                               Urban                        0

# %%
# Cleaning up columns
cleaned_data = medicare_data_df.rename(columns={"Bene_Geo_Desc": "State", "Bene_Mdcd_Mdcr_Enrl_Stus": "Medicare/Medicaid","Bene_Race_Desc": "Race",
                                 "Bene_Sex_Desc": "Sex", "Bene_Mdcr_Entlmt_Stus":"Entitlement Status", "Bene_Age_Desc":"Age","Bene_RUCA_Desc":"Locality","Total_Bene_TH_Elig":"Total Telehealth-Eligible Users",
                                 "Total_PartB_Enrl":"Part B Enrollment","Total_Bene_Telehealth":"Telehealth Users","Pct_Telehealth":"Percent of Telehealth Users"}).dropna().reset_index(drop=True)
cleaned_data.head()
# Out:
#    Year quarter    State    Medicare/Medicaid                    Race  Sex  \
# 0  2023       1  Wyoming        Medicare Only                     All  All
# 1  2023       1  Wyoming  Medicare & Medicaid                     All  All
# 2  2023       1  Wyoming                  All      Non-Hispanic White  All
# 3  2023       1  Wyoming                  All                Hispanic  All
# 4  2023       1  Wyoming                  All  Black/African American  All
#
#   Entitlement Status  Age Locality  Total Telehealth-Eligible Users  \
# 0                All  All      All                          57582.0
# 1                All  All      All                           7781.0
# 2                All  All      All                          59795.0
# 3                All  All      All                           2476.0
# 4                All  All      All                            263.0
#
#    Part B Enrollment  Telehealth Users  Percent of Telehealth Users
# 0            87532.0            3976.0                       0.0690
# 1            10302.0            1373.0                       0.1765
# 2            89194.0            4813.0                       0.0805
# 3             3786.0             213.0                       0.0860
# 4              462.0              33.0                       0.1255

# %%
#Checking total counts by year
cleaned_data.groupby("Year").count()
# Out:
#       quarter  State  Medicare/Medicaid  Race   Sex  Entitlement Status   Age  \
# Year
# 2020     5374   5374               5374  5374  5374                5374  5374
# 2021     5380   5380               5380  5380  5380                5380  5380
# 2022     5375   5375               5375  5375  5375                5375  5375
# 2023     1074   1074               1074  1074  1074                1074  1074
#
#       Locality  Total Telehealth-Eligible Users  Part B Enrollment  \
# Year
# 2020      5374                             5374               5374
# 2021      5380                             5380               5380
# 2022      5375                             5375               5375
# 2023      1074                             1074               1074
#
#       Telehealth Users  Percent of Telehealth Users
# Year
# 2020              5374                         5374
# 2021              5380                         5380
# 2022              5375                         5375
# 2023              1074                         1074

# %%
#Separating National data from State data
national = cleaned_data.loc[(cleaned_data["State"] == "National") & (cleaned_data['quarter']!="Overall")]
state = cleaned_data.loc[(cleaned_data["State"] != "National") & (cleaned_data['quarter']!="Overall")]

# %%
overall_states = state.loc[(state["Age"] == "All") & (state['Entitlement Status']== "All") & (state['Locality']== "All") & (state["Medicare/Medicaid"]== "All") & (state['Race']== "All")
                            & (state['Sex']== "All")].reset_index(drop=True).groupby(["State"])["Percent of Telehealth Users"]
states_means = overall_states.mean()
states_min = overall_states.min()
states_max = overall_states.max()
states_range = states_max - states_min
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Percent of Telehealth Users,_color]
